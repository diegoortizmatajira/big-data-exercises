# %%
import pandas as pd
is_google_colab = 'google.colab' in str(get_ipython())

# %% [markdown]
# Dataset: Kaggle [Mobile price classification](https://www.kaggle.com/iabhishekofficial/mobile-price-classification)

# %%
if is_google_colab:
    print('Running on Google CoLab')
    from google.colab import drive
    drive.mount('/content/drive/', force_remount = True)
    mobile_data = pd.read_csv('/content/drive/My Drive/data/mobile-price-classification.csv', header = 0)
else:
    print('Running Locally')
    mobile_data = pd.read_csv('mobile-price-classification.csv')
# Out:
# Running Locally

# %% [markdown]
# # Data sampling (Sample, Tail, Head)

# %%
mobile_data.sample(5)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 575            1197     1          0.5         1   9       0          20
# 127            1564     0          2.3         0   4       1          25
# 1193           1130     0          1.8         1   0       0          27
# 571            1627     0          0.9         1   9       1          32
# 428            1197     0          1.3         0   3       1          20
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 575     0.1        129        5  ...        214      1710  2885    19     7
# 127     0.5        189        6  ...       1259      1965  1496     6     4
# 1193    0.9        101        1  ...       1495      1579   315    14     5
# 571     0.1        180        6  ...         52      1082  3206    12     6
# 428     0.5        149        6  ...        649      1629  1797    19     5
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
mobile_data.head(3)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
#
# [3 rows x 21 columns]

# %%
# equals to head(3)
mobile_data.iloc[:3]
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
#
# [3 rows x 21 columns]

# %%
# equals to head(3) and iloc[:3]
mobile_data.loc[:2]
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
#
# [3 rows x 21 columns]

# %%
mobile_data.tail(2)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2 rows x 21 columns]

# %%
# equals to tail(2)
mobile_data.iloc[-2:]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2 rows x 21 columns]

# %%
# loc DO NOT WORKS WITH NEGATIVE VALUES
# mobile_data.loc[-2:]

# %% [markdown]
# # Data description

# %%
# shape return rows and columns
mobile_data.shape
# Out:
# (2000, 21)

# %%
# shape return rows and columns
print('Rows: ', mobile_data.shape[0])
print('Columns:', mobile_data.shape[1])
# Out:
# Rows:  2000
# Columns: 21

# %%
mobile_data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
len(mobile_data)
# Out:
# 2000

# %% [markdown]
# # Data query

# %% [markdown]
# ## Get specific columns

# %%
mobile_data.head(2)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
#
# [2 rows x 21 columns]

# %%
mobile_data["battery_power"].head(2)
# Out:
# 0     842
# 1    1021
# Name: battery_power, dtype: int64

# %%
mobile_data.head(2)["battery_power"]
# Out:
# 0     842
# 1    1021
# Name: battery_power, dtype: int64

# %% [markdown]
# ## Get specific values from a row and column

# %%
mobile_data.loc[0]
# Out:
# battery_power     842.0
# blue                0.0
# clock_speed         2.2
# dual_sim            0.0
# fc                  1.0
# four_g              0.0
# int_memory          7.0
# m_dep               0.6
# mobile_wt         188.0
# n_cores             2.0
# pc                  2.0
# px_height          20.0
# px_width          756.0
# ram              2549.0
# sc_h                9.0
# sc_w                7.0
# talk_time          19.0
# three_g             0.0
# touch_screen        0.0
# wifi                1.0
# price_range         1.0
# Name: 0, dtype: float64

# %%
mobile_data.iloc[-1]
# Out:
# battery_power     510.0
# blue                1.0
# clock_speed         2.0
# dual_sim            1.0
# fc                  5.0
# four_g              1.0
# int_memory         45.0
# m_dep               0.9
# mobile_wt         168.0
# n_cores             6.0
# pc                 16.0
# px_height         483.0
# px_width          754.0
# ram              3919.0
# sc_h               19.0
# sc_w                4.0
# talk_time           2.0
# three_g             1.0
# touch_screen        1.0
# wifi                1.0
# price_range         3.0
# Name: 1999, dtype: float64

# %%
mobile_data.iloc[0]
# Out:
# battery_power     842.0
# blue                0.0
# clock_speed         2.2
# dual_sim            0.0
# fc                  1.0
# four_g              0.0
# int_memory          7.0
# m_dep               0.6
# mobile_wt         188.0
# n_cores             2.0
# pc                  2.0
# px_height          20.0
# px_width          756.0
# ram              2549.0
# sc_h                9.0
# sc_w                7.0
# talk_time          19.0
# three_g             0.0
# touch_screen        0.0
# wifi                1.0
# price_range         1.0
# Name: 0, dtype: float64

# %%
# dataframe[column][row]
mobile_data["battery_power"][0]
# Out:
# 842

# %%
# loc [row][column name]
mobile_data.loc[0]['battery_power']
# Out:
# 842.0

# %%
# loc [row][column]
mobile_data.loc[0][0]
# Out:
# 842.0

# %%
# iloc [row][column]
mobile_data.iloc[0][0]
# Out:
# 842.0

# %%
# iloc[row, column]
mobile_data.iloc[0, 0]
# Out:
# 842

# %%
# DOES NOT WORK
# mobile_data.iloc[0,'battery_power']

# %% [markdown]
# ## Get specific ranges

# %%
# loc[from:to]
mobile_data.loc[1:3]
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
#
#    three_g  touch_screen  wifi  price_range
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
#
# [3 rows x 21 columns]

# %%
# loc[:to] equals to loc[0:to]
mobile_data.loc[:3]
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# ...

# %%
# loc[from:] equals to loc[from:last row]
mobile_data.loc[1995:]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
# Gets column ranges from indexes
mobile_data.loc[1][1:5]
# Out:
# blue           1.0
# clock_speed    0.5
# dual_sim       1.0
# fc             0.0
# Name: 1, dtype: float64

# %%
# Gets column ranges from indexes
mobile_data.loc[1][:5]
# Out:
# battery_power    1021.0
# blue                1.0
# clock_speed         0.5
# dual_sim            1.0
# fc                  0.0
# Name: 1, dtype: float64

# %%
# Gets column ranges from indexes
mobile_data.loc[1][10:]
# Out:
# pc                 6.0
# px_height        905.0
# px_width        1988.0
# ram             2631.0
# sc_h              17.0
# sc_w               3.0
# talk_time          7.0
# three_g            1.0
# touch_screen       1.0
# wifi               0.0
# price_range        2.0
# Name: 1, dtype: float64

# %% [markdown]
# ## Iterate for the data

# %%
for i, row in mobile_data.sample(2).iterrows():
    print('Row number: ',i)
    print('Battery Power:', row['battery_power'])
    print('Length: ', len(row))
    print('-----')
# Out:
# Row number:  36
# Battery Power: 589.0
# Length:  21
# -----
# Row number:  1681
# Battery Power: 807.0
# Length:  21
# -----

# %%
for i, column in enumerate(mobile_data.columns):
    print(i, '=>', column)
# Out:
# 0 => battery_power
# 1 => blue
# 2 => clock_speed
# 3 => dual_sim
# 4 => fc
# 5 => four_g
# 6 => int_memory
# 7 => m_dep
# 8 => mobile_wt
# 9 => n_cores
# 10 => pc
# 11 => px_height
# 12 => px_width
# 13 => ram
# 14 => sc_h
# 15 => sc_w
# 16 => talk_time
# 17 => three_g
# 18 => touch_screen
# 19 => wifi
# 20 => price_range
