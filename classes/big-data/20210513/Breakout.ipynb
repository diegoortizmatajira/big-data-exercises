# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Source: [Pokemon](https://www.kaggle.com/brendan45774/pokmon-index-database)

# %%
pwd
# Out:
# 'C:\\Users\\diegoortizmatajira\\Documents\\Personal\\Lambton College\\20210513'

# %%
df=pd.read_csv('publicdomain/pokemon.csv')

# %%
df
# Out:
#      Number       Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 0       001  Bulbasaur   GRASS    318   45      49       49              65
# 1       001  Bulbasaur  POISON    318   45      49       49              65
# 2       002    Ivysaur   GRASS    405   60      62       63              80
# 3       002    Ivysaur  POISON    405   60      62       63              80
# 4       003   Venusaur   GRASS    525   80      82       83             100
# ...     ...        ...     ...    ...  ...     ...      ...             ...
# 1163    716    Xerneas   FAIRY    680  126     131       95             131
# 1164    717    Yveltal    DARK    680  126     131       95             131
# 1165    717    Yveltal  FLYING    680  126     131       95             131
# 1166    718    Zygarde  DRAGON    600  108     100      121              81
# 1167    718    Zygarde  GROUND    600  108     100      121              81
#
#       Special Defense  Speed
# ...

# %%
df.columns
# Out:
# Index(['Number', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense',
#        'Special Attack', 'Special Defense', 'Speed'],
#       dtype='object')

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Total'}>,
#         <AxesSubplot:title={'center':'HP'}>,
#         <AxesSubplot:title={'center':'Attack'}>],
#        [<AxesSubplot:title={'center':'Defense'}>,
#         <AxesSubplot:title={'center':'Special Attack'}>,
#         <AxesSubplot:title={'center':'Special Defense'}>],
#        [<AxesSubplot:title={'center':'Speed'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (1168, 10)

# %%
df.describe()
# Out:
#              Total           HP       Attack      Defense  Special Attack  \
# count  1168.000000  1168.000000  1168.000000  1168.000000     1168.000000
# mean    435.632705    69.525685    78.815925    74.369863       72.619007
# std     116.527166    24.919600    31.714658    30.761824       31.770755
# min     180.000000     1.000000     5.000000     5.000000       10.000000
# 25%     334.000000    50.000000    55.000000    50.000000       50.000000
# 50%     453.000000    66.000000    75.000000    70.000000       65.000000
# 75%     515.000000    82.000000   100.000000    90.000000       95.000000
# max     780.000000   255.000000   190.000000   230.000000      194.000000
#
#        Special Defense        Speed
# count      1168.000000  1168.000000
# mean         71.715753    68.586473
# std          27.265611    28.315690
# min          20.000000     5.000000
# 25%          50.000000    47.000000
# 50%          70.000000    65.500000
# 75%          90.000000    90.000000
# ...

# %%
df.head()
# Out:
#   Number       Name    Type  Total  HP  Attack  Defense  Special Attack  \
# 0    001  Bulbasaur   GRASS    318  45      49       49              65
# 1    001  Bulbasaur  POISON    318  45      49       49              65
# 2    002    Ivysaur   GRASS    405  60      62       63              80
# 3    002    Ivysaur  POISON    405  60      62       63              80
# 4    003   Venusaur   GRASS    525  80      82       83             100
#
#    Special Defense  Speed
# 0               65     45
# 1               65     45
# 2               80     60
# 3               80     60
# 4              100     80

# %%
df.tail()
# Out:
#      Number     Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 1163    716  Xerneas   FAIRY    680  126     131       95             131
# 1164    717  Yveltal    DARK    680  126     131       95             131
# 1165    717  Yveltal  FLYING    680  126     131       95             131
# 1166    718  Zygarde  DRAGON    600  108     100      121              81
# 1167    718  Zygarde  GROUND    600  108     100      121              81
#
#       Special Defense  Speed
# 1163               98     99
# 1164               98     99
# 1165               98     99
# 1166               95     95
# 1167               95     95

# %%
df.mean()
# Out:
# Total              435.632705
# HP                  69.525685
# Attack              78.815925
# Defense             74.369863
# Special Attack      72.619007
# Special Defense     71.715753
# Speed               68.586473
# dtype: float64

# %%
df.mode()
# Out:
#     Number                     Name   Type  Total    HP  Attack  Defense  \
# 0    647.1                Abomasnow  WATER  600.0  60.0    50.0     70.0
# 1    648.1   Aegislash- Blade Forme    NaN    NaN   NaN    65.0      NaN
# 2    681.1  Aegislash- Shield Forme    NaN    NaN   NaN     NaN      NaN
# 3    710.1               Aerodactyl    NaN    NaN   NaN     NaN      NaN
# 4    710.2                   Aggron    NaN    NaN   NaN     NaN      NaN
# ..     ...                      ...    ...    ...   ...     ...      ...
# 391    711                   Zekrom    NaN    NaN   NaN     NaN      NaN
# 392    714                    Zubat    NaN    NaN   NaN     NaN      NaN
# 393    715                 Zweilous    NaN    NaN   NaN     NaN      NaN
# 394    717                  Zygarde    NaN    NaN   NaN     NaN      NaN
# 395    718                      NaN    NaN    NaN   NaN     NaN      NaN
#
#      Special Attack  Special Defense  Speed
# 0              60.0             80.0   60.0
# ...

# %%
df.median()
# Out:
# Number             364.0
# Total              453.0
# HP                  66.0
# Attack              75.0
# Defense             70.0
# Special Attack      65.0
# Special Defense     70.0
# Speed               65.5
# dtype: float64

# %%
df.plot()
# Out:
# <AxesSubplot:>
